# %%
# !sh freesolv_graphkernel.sh
# Out:
# =====Train and evaluate on freesolv (random split seed=122)=====
# INFO:root:Splitting index file specified. Use file.
# INFO:root:Training on dataset freesolv...
# INFO:root:	Computing graph kernel.
# INFO:root:	Training regressor on task 1.
# INFO:root:	Trained model saved to "freesolv_122.pkl".
# INFO:root:Predicting on dataset freesolv...
# INFO:root:	Model loaded.
# INFO:root:	Predictions saved to "freesolv_seed_122.npy".
# INFO:root:	All tasks averaged score (RMSE): 1.740600.
#
# =====Train and evaluate on freesolv (random split seed=123)=====
# INFO:root:Splitting index file specified. Use file.
# INFO:root:Training on dataset freesolv...
# INFO:root:	Computing graph kernel.
# INFO:root:	Training regressor on task 1.
# INFO:root:	Trained model saved to "freesolv_123.pkl".
# INFO:root:Predicting on dataset freesolv...
# INFO:root:	Model loaded.
# INFO:root:	Predictions saved to "freesolv_seed_123.npy".
# INFO:root:	All tasks averaged score (RMSE): 1.207438.
#
# ...

# %%
# !sh freesolv_seqkernel.sh
# Out:
# =====Train and evaluate on freesolv (random split seed=122)=====
# INFO:root:Splitting index file specified. Use file.
# INFO:root:Training on dataset freesolv...
# INFO:root:	Computing sequence kernel.
# INFO:root:	Training regressor on task 1.
# INFO:root:	Trained model saved to "freesolv_122.pkl".
# INFO:root:Predicting on dataset freesolv...
# INFO:root:	Model loaded.
# INFO:root:	Predictions saved to "freesolv_seed_122.npy".
# INFO:root:	All tasks averaged score (RMSE): 1.183357.
#
# =====Train and evaluate on freesolv (random split seed=123)=====
# INFO:root:Splitting index file specified. Use file.
# INFO:root:Training on dataset freesolv...
# INFO:root:	Computing sequence kernel.
# INFO:root:	Training regressor on task 1.
# INFO:root:	Trained model saved to "freesolv_123.pkl".
# INFO:root:Predicting on dataset freesolv...
# INFO:root:	Model loaded.
# INFO:root:	Predictions saved to "freesolv_seed_123.npy".
# INFO:root:	All tasks averaged score (RMSE): 1.284688.
#
# ...

# %%
# !sh clintox_seqkernel.sh
# Out:
# =====Train and evaluate on clintox (random split seed=122)=====
# INFO:root:Splitting index file specified. Use file.
# INFO:root:Training on dataset clintox...
# INFO:root:	Computing sequence kernel.
# INFO:root:	Training classifier on task 1.
# INFO:root:	Training classifier on task 2.
# INFO:root:	Trained model saved to "clintox_122.pkl".
# INFO:root:Predicting on dataset clintox...
# INFO:root:	Model loaded.
# INFO:root:	Predictions saved to "clintox_seed_122.npy".
# INFO:root:	All tasks averaged score (ROC): 0.974264.
#
# =====Train and evaluate on clintox (random split seed=123)=====
# INFO:root:Splitting index file specified. Use file.
# INFO:root:Training on dataset clintox...
# INFO:root:	Computing sequence kernel.
# INFO:root:	Training classifier on task 1.
# INFO:root:	Training classifier on task 2.
# INFO:root:	Trained model saved to "clintox_123.pkl".
# INFO:root:Predicting on dataset clintox...
# INFO:root:	Model loaded.
# ...

# %%
# !sh sider_graphkernel.sh
# Out:
# =====Train and evaluate on sider (random split seed=122)=====
# INFO:root:Splitting index file specified. Use file.
# INFO:root:Training on dataset sider...
# INFO:root:	Computing graph kernel.
# INFO:root:	Training classifier on task 1.
# INFO:root:	Training classifier on task 2.
# INFO:root:	Training classifier on task 3.
# INFO:root:	Training classifier on task 4.
# INFO:root:	Training classifier on task 5.
# INFO:root:	Training classifier on task 6.
# INFO:root:	Training classifier on task 7.
# INFO:root:	Training classifier on task 8.
# INFO:root:	Training classifier on task 9.
# INFO:root:	Training classifier on task 10.
# INFO:root:	Training classifier on task 11.
# INFO:root:	Training classifier on task 12.
# INFO:root:	Training classifier on task 13.
# INFO:root:	Training classifier on task 14.
# INFO:root:	Training classifier on task 15.
# INFO:root:	Training classifier on task 16.
# INFO:root:	Training classifier on task 17.
# INFO:root:	Training classifier on task 18.
# ...
